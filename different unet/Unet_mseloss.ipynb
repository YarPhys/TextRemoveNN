# %%
import tensorflow as tf
from IPython.display import clear_output
import numpy as np
import os
import pathlib
import time
import datetime
from tensorflow.keras import datasets, layers, models
from matplotlib import pyplot as plt
from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gpu = tf.config.list_physical_devices('GPU')[0]
tf.config.experimental.set_memory_growth(gpu, True)

physical_devices = tf.config.list_physical_devices('GPU') 
print("Number of GPUs :", len(physical_devices)) 
print("Tensorflow GPU :",tf.test.is_built_with_cuda())
# Out:
# Number of GPUs : 1
# Tensorflow GPU : True

# %%
if len(physical_devices)>0:
    device="/GPU:0"
else:
    device="/CPU:0"

# %%
import cv2
from tqdm import tqdm
data_dir = "C:/Users/iaren/Videos/Captures/Ultradata"
data_dir_train = "C:/Users/iaren/Videos/Captures/Ultradata/train"
data_dir_test = "C:/Users/iaren/Videos/Captures/Ultradata/test"
data_dir, data_dir_train, data_dir_test = pathlib.Path(data_dir), pathlib.Path(data_dir_train), pathlib.Path(data_dir_test) 
image_count = len(list(data_dir_train.glob('*.jpg')))#  + len(list(data_dir_test.glob('*.jpg')))
print(image_count)
# Out:
# 292

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

def decode_img(img):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=3)
  # Resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
PATH = data_dir.parent/data_dir_train

list(PATH.parent.iterdir())

sample_image = tf.io.read_file(str(PATH / '0 (1).jpg'))
sample_image = tf.io.decode_jpeg(sample_image)
print(sample_image.shape)
plt.figure()
plt.imshow(sample_image)
# Out:
# (256, 512, 3)

# %%
def load(image_file):
  # Read and decode an image file to a uint8 tensor
  image = tf.io.read_file(image_file)
  image = tf.io.decode_jpeg(image)

  # Split each image tensor into two tensors:
  # - one with a real building facade image
  # - one with an architecture label image 
  w = tf.shape(image)[1]
  w = w // 2
  input_image = image[:, :w, :]
  real_image = image[:, w:, :]

  # Convert both images to float32 tensors
  input_image = tf.cast(input_image, tf.float32)
  real_image = tf.cast(real_image, tf.float32)

  return input_image, real_image

# %%
inp, re = load(str(PATH / '0 (1).jpg'))
# Casting to int for matplotlib to display the images
plt.figure()
plt.imshow(inp / 255.0)
plt.figure()
plt.imshow(re / 255.0)

# %%
# The facade training set consist of 400 images
BUFFER_SIZE = 292
# The batch size of 1 produced better results for the U-Net in the original pix2pix experiment
BATCH_SIZE = 1

IMG_WIDTH = 256
IMG_HEIGHT = 256
# for i in range (1, 99, 1):
#     sample_image = tf.io.read_file(str(PATH / f'0 ({i}).jpg'))
#     sample_image = tf.io.decode_jpeg(sample_image)
#     x, y, z = sample_image.shape
#     width.append(x)
#     height.append(y)
print(IMG_WIDTH)
print(IMG_HEIGHT)
# Out:
# 256
# 256

# %%
def resize(input_image, real_image, height, width):
  input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
  real_image = tf.image.resize(real_image, [height, width],
                               method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

  return input_image, real_image

def random_crop(input_image, real_image):
  stacked_image = tf.stack([input_image, real_image], axis=0)
  cropped_image = tf.image.random_crop(
      stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])

  return cropped_image[0], cropped_image[1]

# Normalizing the images to [-1, 1]
def normalize(input_image, real_image):
  input_image = (input_image / 127.5) - 1
  real_image = (real_image / 127.5) - 1

  return input_image, real_image

# %%
@tf.function()
def random_jitter(input_image, real_image):
  # Resizing to 286x286
  input_image, real_image = resize(input_image, real_image, 286, 286)

  # Random cropping back to ...
  input_image, real_image = random_crop(input_image, real_image)

  if tf.random.uniform(()) > 0.5:
    # Random mirroring
    input_image = tf.image.flip_left_right(input_image)
    real_image = tf.image.flip_left_right(real_image)

  return input_image, real_image

# %%
plt.figure(figsize=(6, 6))
for i in range(4):
  rj_inp, rj_re = random_jitter(inp, re)
  plt.subplot(2, 2, i + 1)
  plt.imshow(rj_inp / 255.0)
  plt.axis('off')
plt.show()

# %%
def load_image_train(image_file):
  input_image, real_image = load(image_file)
  input_image, real_image = random_jitter(input_image, real_image)
  input_image, real_image = normalize(input_image, real_image)

  return input_image, real_image

def load_image_test(image_file):
  input_image, real_image = load(image_file)
  input_image, real_image = resize(input_image, real_image,
                                   IMG_HEIGHT, IMG_WIDTH)
  input_image, real_image = normalize(input_image, real_image)

  return input_image, real_image

# %%
train_dataset = tf.data.Dataset.list_files(str(data_dir_train/'*'))
train_dataset = train_dataset.map(load_image_train,
                                  num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE) 


try:
  test_dataset = tf.data.Dataset.list_files(str(data_dir/'test/*'))
except tf.errors.InvalidArgumentError:
  test_dataset = tf.data.Dataset.list_files(str(data_dir/'test/*'))
test_dataset = test_dataset.map(load_image_test)
test_dataset = test_dataset.batch(BATCH_SIZE) 
print(type(test_dataset))
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.BatchDataset'>

# %%
print(list(train_dataset.as_numpy_iterator()))

# %%
print(test_dataset)
# Out:
# <BatchDataset shapes: ((None, 256, 256, None), (None, 256, 256, None)), types: (tf.float32, tf.float32)>

# %%
fileList=[]
fl=[]
for dirname, _, filenames in os.walk('C:/Users/iaren/PycharmProjects/TextRemoveNN/ultaa/train'):
    for filename in filenames:
        fileList.append(os.path.join(dirname, filename))
for i in fileList:
    if i.endswith('.jpg'):
        fl.append(i)
fileList=np.array(fl)

# %%
from PIL import Image
fl=[]
for filename in fileList:
    
    try:
      img = Image.open(filename)# open the image file
      img.verify() # verify that it is, in fact an image
      fl.append(filename)
    except Exception:
        print("Bad File",filename)
fileList=np.array(fl)
np.random.shuffle(fileList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [155], in <cell line: 3>()
#       1 from PIL import Image
#       2 fl=[]
# ----> 3 for filename in fileList:
#       5     try:
#       6       img = Image.open(filename)# open the image file
#
# NameError: name 'fileList' is not defined

# %%
batch = 1
def decode_img(x):
    x=tf.io.read_file(x)
    x=tf.image.decode_jpeg(x,channels=3)
    x=tf.image.resize(x,(256,256))
    return x

def rgb_to_gs(x):
    gs = tf.image.rgb_to_grayscale(x)
    gs=tf.math.divide(gs,255)
    return gs


def create_dataset(filename_list):
    df=tf.data.Dataset.from_tensor_slices(filename_list)
    im=df.map(decode_img)
    gs=im.map(rgb_to_gs)
    df=tf.data.Dataset.zip((gs,im))
    df=df.batch(batch)
    df=df.prefetch(tf.data.experimental.AUTOTUNE)
    return df
#These are the actual objects representing the input pipeline for Training and Testing
train_df=create_dataset(fileList[:int(len(fileList)*0.8)])
test_df=create_dataset(fileList[int(len(fileList)*0.8):])

# %%
print(type(train_df))
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>

# %% [markdown]
# # Model

# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)


def unet():
    input = Input(shape=(256, 256, 3))
    
    x = tf.keras.layers.Conv2D(64, 3, activation = 'relu', padding = "same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(64, 3, activation = 'relu', padding = "same")(x)
    x1 = tf.keras.layers.BatchNormalization()(x)
    print(x1.shape)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x1)
    
    x = tf.keras.layers.Conv2D(128, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(128, 3, activation = 'relu',  padding = "same")(x)
    x2 = tf.keras.layers.BatchNormalization()(x)
    print(x2.shape)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x2)
    
    x = tf.keras.layers.Conv2D(256, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(256, 3, activation = 'relu',  padding = "same")(x)
    x3 = tf.keras.layers.BatchNormalization()(x)
    print(x3.shape)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x3)

    x = tf.keras.layers.Conv2D(512, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(512, 3, activation = 'relu',  padding = "same")(x)
    x4 = tf.keras.layers.BatchNormalization()(x)
    print(x4.shape)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x4)
    
    x = tf.keras.layers.Conv2DTranspose(512, 2, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Resizing(32, 32)(x)
    print(x.shape)
    x = tf.keras.layers.Concatenate(axis=1)([x, x4])
    x = tf.keras.layers.Resizing(64, 64)(x)
    x = tf.keras.layers.Conv2D(512, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(512, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    
    x = tf.keras.layers.Conv2DTranspose(256, 2, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    print(x.shape)
    x = tf.keras.layers.Concatenate(axis=1)([x, x3])
    x = tf.keras.layers.Resizing(128, 128)(x)
    x = tf.keras.layers.Conv2D(256, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(256, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    
    x = tf.keras.layers.Conv2DTranspose(128, 2, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    print(x.shape)
    x = tf.keras.layers.Concatenate()([x, x2])
    x = tf.keras.layers.Resizing(256, 256)(x)
    x = tf.keras.layers.Conv2D(128, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(128, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    
    x = tf.keras.layers.Conv2DTranspose(64, 2, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    print(x.shape)
    x = tf.keras.layers.Concatenate()([x, x1])
    x = tf.keras.layers.Resizing(256, 256)(x)
    x = tf.keras.layers.Conv2D(64, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(64, 3, activation = 'relu',  padding = "same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    
    x = tf.keras.layers.Conv2D(3, 3, padding = "same")(x)
    x = tf.keras.layers.Activation('sigmoid')(x)
    
    model = Model(inputs=[input], outputs=[x])

    model.compile(optimizer='adam', loss=dice_coef_loss, metrics=[dice_coef])

    return model

# %%
model = unet()
# Out:
# (None, 256, 256, 64)
# (None, 128, 128, 128)
# (None, 64, 64, 256)
# (None, 32, 32, 512)
# (None, 32, 32, 512)
# (None, 64, 64, 256)
# (None, 128, 128, 128)
# (None, 256, 256, 64)

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_56 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_501 (Conv2D)             (None, 256, 256, 64) 1792        input_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_566 (BatchN (None, 256, 256, 64) 256         conv2d_501[0][0]
# __________________________________________________________________________________________________
# conv2d_502 (Conv2D)             (None, 256, 256, 64) 36928       batch_normalization_566[0][0]
# __________________________________________________________________________________________________
# batch_normalization_567 (BatchN (None, 256, 256, 64) 256         conv2d_502[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_183 (MaxPooling2D (None, 128, 128, 64) 0           batch_normalization_567[0][0]
# __________________________________________________________________________________________________
# conv2d_503 (Conv2D)             (None, 128, 128, 128 73856       max_pooling2d_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_568 (BatchN (None, 128, 128, 128 512         conv2d_503[0][0]
# __________________________________________________________________________________________________
# conv2d_504 (Conv2D)             (None, 128, 128, 128 147584      batch_normalization_568[0][0]
# __________________________________________________________________________________________________
# batch_normalization_569 (BatchN (None, 128, 128, 128 512         conv2d_504[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_184 (MaxPooling2D (None, 64, 64, 128)  0           batch_normalization_569[0][0]
# __________________________________________________________________________________________________
# conv2d_505 (Conv2D)             (None, 64, 64, 256)  295168      max_pooling2d_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_570 (BatchN (None, 64, 64, 256)  1024        conv2d_505[0][0]
# __________________________________________________________________________________________________
# conv2d_506 (Conv2D)             (None, 64, 64, 256)  590080      batch_normalization_570[0][0]
# __________________________________________________________________________________________________
# batch_normalization_571 (BatchN (None, 64, 64, 256)  1024        conv2d_506[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_185 (MaxPooling2D (None, 32, 32, 256)  0           batch_normalization_571[0][0]
# __________________________________________________________________________________________________
# conv2d_507 (Conv2D)             (None, 32, 32, 512)  1180160     max_pooling2d_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_572 (BatchN (None, 32, 32, 512)  2048        conv2d_507[0][0]
# __________________________________________________________________________________________________
# conv2d_508 (Conv2D)             (None, 32, 32, 512)  2359808     batch_normalization_572[0][0]
# __________________________________________________________________________________________________
# batch_normalization_573 (BatchN (None, 32, 32, 512)  2048        conv2d_508[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_186 (MaxPooling2D (None, 16, 16, 512)  0           batch_normalization_573[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_86 (Conv2DTran (None, 16, 16, 512)  1049088     max_pooling2d_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_574 (BatchN (None, 16, 16, 512)  2048        conv2d_transpose_86[0][0]
# __________________________________________________________________________________________________
# resizing_29 (Resizing)          (None, 32, 32, 512)  0           batch_normalization_574[0][0]
# __________________________________________________________________________________________________
# concatenate_85 (Concatenate)    (None, 64, 32, 512)  0           resizing_29[0][0]
#                                                                  batch_normalization_573[0][0]
# __________________________________________________________________________________________________
# resizing_30 (Resizing)          (None, 64, 64, 512)  0           concatenate_85[0][0]
# __________________________________________________________________________________________________
# conv2d_509 (Conv2D)             (None, 64, 64, 512)  2359808     resizing_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_575 (BatchN (None, 64, 64, 512)  2048        conv2d_509[0][0]
# __________________________________________________________________________________________________
# conv2d_510 (Conv2D)             (None, 64, 64, 512)  2359808     batch_normalization_575[0][0]
# __________________________________________________________________________________________________
# batch_normalization_576 (BatchN (None, 64, 64, 512)  2048        conv2d_510[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_87 (Conv2DTran (None, 64, 64, 256)  524544      batch_normalization_576[0][0]
# __________________________________________________________________________________________________
# batch_normalization_577 (BatchN (None, 64, 64, 256)  1024        conv2d_transpose_87[0][0]
# __________________________________________________________________________________________________
# concatenate_86 (Concatenate)    (None, 128, 64, 256) 0           batch_normalization_577[0][0]
#                                                                  batch_normalization_571[0][0]
# __________________________________________________________________________________________________
# resizing_31 (Resizing)          (None, 128, 128, 256 0           concatenate_86[0][0]
# __________________________________________________________________________________________________
# conv2d_511 (Conv2D)             (None, 128, 128, 256 590080      resizing_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_578 (BatchN (None, 128, 128, 256 1024        conv2d_511[0][0]
# __________________________________________________________________________________________________
# conv2d_512 (Conv2D)             (None, 128, 128, 256 590080      batch_normalization_578[0][0]
# __________________________________________________________________________________________________
# batch_normalization_579 (BatchN (None, 128, 128, 256 1024        conv2d_512[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_88 (Conv2DTran (None, 128, 128, 128 131200      batch_normalization_579[0][0]
# __________________________________________________________________________________________________
# batch_normalization_580 (BatchN (None, 128, 128, 128 512         conv2d_transpose_88[0][0]
# __________________________________________________________________________________________________
# concatenate_87 (Concatenate)    (None, 128, 128, 256 0           batch_normalization_580[0][0]
#                                                                  batch_normalization_569[0][0]
# __________________________________________________________________________________________________
# resizing_32 (Resizing)          (None, 256, 256, 256 0           concatenate_87[0][0]
# __________________________________________________________________________________________________
# conv2d_513 (Conv2D)             (None, 256, 256, 128 295040      resizing_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_581 (BatchN (None, 256, 256, 128 512         conv2d_513[0][0]
# __________________________________________________________________________________________________
# conv2d_514 (Conv2D)             (None, 256, 256, 128 147584      batch_normalization_581[0][0]
# __________________________________________________________________________________________________
# batch_normalization_582 (BatchN (None, 256, 256, 128 512         conv2d_514[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_89 (Conv2DTran (None, 256, 256, 64) 32832       batch_normalization_582[0][0]
# __________________________________________________________________________________________________
# batch_normalization_583 (BatchN (None, 256, 256, 64) 256         conv2d_transpose_89[0][0]
# __________________________________________________________________________________________________
# concatenate_88 (Concatenate)    (None, 256, 256, 128 0           batch_normalization_583[0][0]
#                                                                  batch_normalization_567[0][0]
# __________________________________________________________________________________________________
# resizing_33 (Resizing)          (None, 256, 256, 128 0           concatenate_88[0][0]
# __________________________________________________________________________________________________
# conv2d_515 (Conv2D)             (None, 256, 256, 64) 73792       resizing_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_584 (BatchN (None, 256, 256, 64) 256         conv2d_515[0][0]
# __________________________________________________________________________________________________
# conv2d_516 (Conv2D)             (None, 256, 256, 64) 36928       batch_normalization_584[0][0]
# __________________________________________________________________________________________________
# batch_normalization_585 (BatchN (None, 256, 256, 64) 256         conv2d_516[0][0]
# __________________________________________________________________________________________________
# conv2d_517 (Conv2D)             (None, 256, 256, 3)  1731        batch_normalization_585[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 3)  0           conv2d_517[0][0]
# ==================================================================================================
# Total params: 12,897,091
# Trainable params: 12,887,491
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
mod_output = model(inp[tf.newaxis, ...], training=False)
plt.imshow(mod_output[0, ...])

# %%
def generate_images(model, test_input, tar):
  prediction = model(test_input, training=True)
  plt.figure(figsize=(15, 15))

  display_list = [test_input[0], tar[0], prediction[0]]
  title = ['Input Image', 'Ground Truth', 'Predicted Image']

  for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.title(title[i])
    # Getting the pixel values in the [0, 1] range to plot.
    plt.imshow(display_list[i] * 0.5 + 0.5)
    plt.axis('off')
  plt.show()

for inp, tar in test_dataset.take(3):
  generate_images(model, inp, tar)

# %%
model.compile(optimizer='RMSprop',
              loss='mse',
              metrics=['accuracy'])

history = model.fit(train_dataset, epochs=35, batch_size=4, 
                    validation_data=test_dataset)
# Out:
# Epoch 1/35
# 292/292 [==============================] - 110s 357ms/step - loss: 0.1425 - accuracy: 0.6132 - val_loss: 0.1838 - val_accuracy: 0.6250
# Epoch 2/35
# 292/292 [==============================] - 105s 357ms/step - loss: 0.1422 - accuracy: 0.6135 - val_loss: 0.1822 - val_accuracy: 0.6463
# Epoch 3/35
# 292/292 [==============================] - 101s 342ms/step - loss: 0.1414 - accuracy: 0.6028 - val_loss: 0.1854 - val_accuracy: 0.6572
# Epoch 4/35
# 292/292 [==============================] - 108s 363ms/step - loss: 0.1430 - accuracy: 0.6076 - val_loss: 0.1848 - val_accuracy: 0.6706
# Epoch 5/35
# 292/292 [==============================] - 101s 343ms/step - loss: 0.1411 - accuracy: 0.6125 - val_loss: 0.1831 - val_accuracy: 0.6376
# Epoch 6/35
# 292/292 [==============================] - 102s 344ms/step - loss: 0.1422 - accuracy: 0.6066 - val_loss: 0.1811 - val_accuracy: 0.6518
# Epoch 7/35
# 292/292 [==============================] - 104s 344ms/step - loss: 0.1428 - accuracy: 0.6106 - val_loss: 0.1808 - val_accuracy: 0.6629
# Epoch 8/35
# 292/292 [==============================] - 102s 344ms/step - loss: 0.1418 - accuracy: 0.6008 - val_loss: 0.1820 - val_accuracy: 0.6419
# Epoch 9/35
# 292/292 [==============================] - 110s 366ms/step - loss: 0.1416 - accuracy: 0.5993 - val_loss: 0.1815 - val_accuracy: 0.6673
# Epoch 10/35
# 292/292 [==============================] - 101s 343ms/step - loss: 0.1420 - accuracy: 0.6002 - val_loss: 0.1809 - val_accuracy: 0.6370
# Epoch 11/35
# 292/292 [==============================] - 102s 344ms/step - loss: 0.1427 - accuracy: 0.6019 - val_loss: 0.1812 - val_accuracy: 0.6741
# Epoch 12/35
# 292/292 [==============================] - 102s 344ms/step - loss: 0.1424 - accuracy: 0.6015 - val_loss: 0.1816 - val_accuracy: 0.6208
# Epoch 13/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1425 - accuracy: 0.6063 - val_loss: 0.1811 - val_accuracy: 0.6502
# Epoch 14/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1419 - accuracy: 0.6088 - val_loss: 0.1826 - val_accuracy: 0.6592
# Epoch 15/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1411 - accuracy: 0.6154 - val_loss: 0.1808 - val_accuracy: 0.6461
# Epoch 16/35
# 292/292 [==============================] - 102s 345ms/step - loss: 0.1416 - accuracy: 0.6141 - val_loss: 0.1816 - val_accuracy: 0.6539
# Epoch 17/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1421 - accuracy: 0.6186 - val_loss: 0.1824 - val_accuracy: 0.6705
# Epoch 18/35
# 292/292 [==============================] - 102s 344ms/step - loss: 0.1410 - accuracy: 0.5979 - val_loss: 0.1811 - val_accuracy: 0.6838
# Epoch 19/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1412 - accuracy: 0.6147 - val_loss: 0.1817 - val_accuracy: 0.7088
# Epoch 20/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1417 - accuracy: 0.6092 - val_loss: 0.1808 - val_accuracy: 0.6466
# Epoch 21/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1400 - accuracy: 0.6136 - val_loss: 0.1839 - val_accuracy: 0.7201
# Epoch 22/35
# 292/292 [==============================] - 101s 343ms/step - loss: 0.1412 - accuracy: 0.6162 - val_loss: 0.1847 - val_accuracy: 0.6195
# Epoch 23/35
# 292/292 [==============================] - 103s 349ms/step - loss: 0.1409 - accuracy: 0.6024 - val_loss: 0.1816 - val_accuracy: 0.6709
# Epoch 24/35
# 292/292 [==============================] - 102s 345ms/step - loss: 0.1406 - accuracy: 0.6131 - val_loss: 0.1805 - val_accuracy: 0.6838
# Epoch 25/35
# 292/292 [==============================] - 102s 345ms/step - loss: 0.1405 - accuracy: 0.6033 - val_loss: 0.1818 - val_accuracy: 0.7229
# Epoch 26/35
# 292/292 [==============================] - 102s 345ms/step - loss: 0.1413 - accuracy: 0.6198 - val_loss: 0.1819 - val_accuracy: 0.6672
# Epoch 27/35
# 292/292 [==============================] - 103s 348ms/step - loss: 0.1399 - accuracy: 0.5980 - val_loss: 0.1818 - val_accuracy: 0.6870
# Epoch 28/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1417 - accuracy: 0.6152 - val_loss: 0.1803 - val_accuracy: 0.6868
# Epoch 29/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1405 - accuracy: 0.6080 - val_loss: 0.1810 - val_accuracy: 0.6058
# Epoch 30/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1413 - accuracy: 0.6107 - val_loss: 0.1815 - val_accuracy: 0.6844
# Epoch 31/35
# 292/292 [==============================] - 103s 349ms/step - loss: 0.1417 - accuracy: 0.6151 - val_loss: 0.1811 - val_accuracy: 0.7065
# Epoch 32/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1420 - accuracy: 0.6033 - val_loss: 0.1808 - val_accuracy: 0.6995
# Epoch 33/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1411 - accuracy: 0.6093 - val_loss: 0.1805 - val_accuracy: 0.6668
# Epoch 34/35
# 292/292 [==============================] - 101s 344ms/step - loss: 0.1396 - accuracy: 0.6136 - val_loss: 0.1820 - val_accuracy: 0.6957
# Epoch 35/35
# 292/292 [==============================] - 103s 349ms/step - loss: 0.1398 - accuracy: 0.6170 - val_loss: 0.1807 - val_accuracy: 0.6426

# %%
for inp, tar in test_dataset.take(3):
  generate_images(model, inp, tar)

# %%
plt.figure(figsize=(10, 5), dpi=300)
plt.semilogy(history.history['loss'])
plt.semilogy(history.history['val_loss'])

# %%
model.evaluate(test_dataset)
# Out:
# 192/192 [==============================] - 17s 87ms/step - loss: 0.1807 - accuracy: 0.6405
# [0.18065212666988373, 0.6405110955238342]

# %%
model.save("first_unet_mse.h5")

# %%
from tensorflow.keras.models import Model, load_model
model = load_model("first_unet.h5")
